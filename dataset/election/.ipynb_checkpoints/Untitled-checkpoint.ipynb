# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("원본.csv",index_col=0)
data["선거 종류"] = data["선거 종류"].apply(lambda x: x.replace("·","").replace(" ",""))
data["당선여부"] = data["당선여부"].astype(bool)
data["경력_지역"] = data["경력_지역"].astype(bool)

# %% [markdown]
# 원본 데이터 컬럼 및 데이터 형
#
# 컬럼|type
# --|--
# 성명|String
# 지역|String
# 선거구명 | String
# 선거 종류 | String
# 회차 | Int
# 기호 | Int
# 성별 | String
# 정당명 | String
# 연령 | Int
# 직업 | String
# 여당평가 | Float
# 당선여부 | Bool
# 득표수(득표율) | Float
# 학교 | String
# 과목 | String
# 경력_지역 | Bool
# 인지도 | Float
# 지역구분 | Int

# %% [markdown]
# 각 원본데이터의 컬럼 pair를 나타내며, ""는 사라진 컬럼을 의미함
# 기본적으로 사라진 컬럼은 Null로 넣으면 되지만 선거종류의 경우 원본데이터 제목에 명시돼있으므로 자동으로 넣는다.

# %%
원본 = ['성명', '지역', '선거구명', '선거 종류', '회차', '기호', '성별', '정당명', '연령', '직업',
      '여당평가', '당선여부', '득표수(득표율)', '학교', '과목', '경력_지역', '인지도', '지역구분']
국회의원 = ['이름', '선거구명1', '선거구명2', '종류', '회', '기호', '남여', '정당', '연령', '직업',
        '여당평가', '당선여부', '득표율',      '학교', '과목', ""        , '인지', '지역구분']
시도지사선거 = ['성명', '지역', '선거구명', '선거 종류', '', '기호', '', '정당명', '연령', '직업',
      '여당평가', '당선여부', '득표수(득표율)', '학력', '', '', '인지도', '지역구분']
구시군의장선거 = ['이름', '선거구명1', '선거구명2', '종류', '회', '기호', '남여', '정당', '연령', '직업',
           '여당평가', '당선여부', '득표율',      '', '', ""        , '', '지역구분']
# 선거종류 자동으로 넣기
시도의회의원선거 = ['성명', '선거구1', '선거구2', '', '', '', '', '', '', '',
            '여당평가', '당선여부', '득표수(득표율)', '학력', '과목', '경력_지역', '인지도', '지역구분']
구시군의회의원선거 = ['이름', '위치', '선거구', '', '회', '몇번', 'gender', '정당', '나이', 'job',
      '당시여당평가', '당선', '득표율', '학력', '과', '경력', '인지', '지역구분']

# %%
for a in data["선거 종류"].unique():
    print((data["선거 종류"] == a).sum())
# Out:
# 2929
# 183
# 2180
# 4752
# 16413

# %%
5471 *3
# Out:
# 16413

# %% [markdown]
# 원본데이터 변경사항-> 각 원본 데이터 마다 여러개의 데이터가 존재함 -> 1번부터 2번까지 순서대로 등록
#
# 데이터이름|기본 행개수|all NULL행 추가 row|1번 제외 전체 value NULL 비율|데이터 내 중복 개수|데이터간 중복열 추가
# --|--|--|--|--|--
# 국회의원1|1000|1%|2%|146개|2데이터 100개
# 국회의원2|1929||8%|98개|
# 시도지사선거1|183||4%|13개|
# 구시군의장선거1|500||2%|190개|
# 구시군의장선거2|1000||1%|145개|1 데이터 100개
# 구시군의장선거3|680||4%|349개|1,2데이터 100,100개
# 시도의회의원선거1|1200|2%|5%|28개|
# 시도의회의원선거2|1200||7%|1000개|3번 데이터 1000개
# 시도의회의원선거3|2352||3%|13개|
# 구시군의회의원선거1|5471|3%|5%|2600개|
# 구시군의회의원선거2|5471||6%|10개|
# 구시군의회의원선거3|5471|10%|2%||1번, 2번 데이터 각 2500개

# %%
names = ['국회의원1', '국회의원2', '시도지사선거1', '구시군의장선거1','구시군의장선거2','구시군의장선거3',
 '시도의회의원선거1','시도의회의원선거2','시도의회의원선거3', '구시군의회의원선거1', '구시군의회의원선거2', '구시군의회의원선거3']
col = [국회의원, 국회의원, 시도지사선거, 구시군의장선거, 구시군의장선거, 구시군의장선거,
       시도의회의원선거,시도의회의원선거,시도의회의원선거, 구시군의회의원선거, 구시군의회의원선거, 구시군의회의원선거]
rows = [(0,1000), (1000,2929),(0,183), (0,500), (500,1500), (1500,2180), (0,1200), (1200, 2400), (2400, 4752),
        (0,5471), (5471, 10942), (10942, 16413)]
null_rows = [0.01, 0,0,0,0,0,0.02,0,0,0.03,0,0.1]
null_vals = [0.02, 0.08, 0.04, 0.02, 0.01, 0.04, 0.05, 0.07, 0.03, 0.05, 0.06, 0.02]
dup1s = [146,98,13,190,145,349,28,1000,13,2600,10,0]
dup2s = [[(2,100)],None,None,None,[(1,100)],[(1,100),(2,100)],None,[(3,1000)],None,None,None,[(1,2500),(2,2500)]]
for i in range(12):
    origin = data[data["선거 종류"] == names[i][:-1]].reset_index(drop=True)
    origin = origin[rows[i][0]:rows[i][1]].reset_index(drop=True)
    tmp = origin.copy()
    na = pd.DataFrame( columns = tmp.columns,index = range(len(origin),int(len(origin) + len(origin) * null_rows[11])))
    if len(na) != 0:
        tmp = pd.concat([tmp,na])
# Out:
#        성명   지역 선거구명      선거 종류   회차   기호   성별  정당명   연령   직업   여당평가   당선여부  \
# 0     박남규   서울  노원구  구시군의회의원선거    5    3    남  rem   56  NaN  47.25  False
# 1     원기복   서울  노원구  구시군의회의원선거    5    3    남  con   51  NaN  47.25   True
# 2     우진철   서울  노원구  구시군의회의원선거    5    3    남  con   34  NaN  47.25  False
# 3     김운종   서울  노원구  구시군의회의원선거    5    3    남  rev   57  정당인  47.25  False
# 4     김치환   서울  노원구  구시군의회의원선거    5    3    남  rev   51  NaN  47.25  False
# ...   ...  ...  ...        ...  ...  ...  ...  ...  ...  ...    ...    ...
# 6013  NaN  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 6014  NaN  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 6015  NaN  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 6016  NaN  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 6017  NaN  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN
#
#       득표수(득표율)   학교   과목  경력_지역       인지도 지역구분
# 0    -2.440819  NaN  NaN   True  0.003845    2
# 1    -0.902033  NaN  NaN  False  0.000011    2
# 2    -1.947384  NaN  NaN  False  0.000212    2
# 3    -1.330125  NaN  NaN  False  0.000076    2
# 4    -1.253592  NaN   경영  False  0.000787    2
# ...        ...  ...  ...    ...       ...  ...
# 6013       NaN  NaN  NaN    NaN       NaN  NaN
# 6014       NaN  NaN  NaN    NaN       NaN  NaN
# 6015       NaN  NaN  NaN    NaN       NaN  NaN
# 6016       NaN  NaN  NaN    NaN       NaN  NaN
# 6017       NaN  NaN  NaN    NaN       NaN  NaN
#
# [6018 rows x 18 columns]

# %%
data[data["선거 종류"] == "국회의원"]
# Out:
#        성명  지역  선거구명 선거 종류  회차  기호 성별  정당명  연령   직업    여당평가  당선여부  득표수(득표율)  \
# 0     오세훈  서울   종로구  국회의원  20   1  남  con  55  NaN  42.840     0 -0.428450
# 1     정세균  서울   종로구  국회의원  20   2  남  rev  65  NaN  42.840     1  0.089372
# 2     박태순  서울   종로구  국회의원  20   3  남  rev  53  NaN  42.840     0 -2.831257
# 3     윤공규  서울   종로구  국회의원  20   3  남  rev  52  정당인  42.840     0 -5.216868
# 4     김한울  서울   종로구  국회의원  20   3  남  rev  37  NaN  42.840     0 -5.478512
# ...   ...  ..   ...   ...  ..  .. ..  ...  ..  ...     ...   ...       ...
# 2924  김재윤  제주  서귀포시  국회의원  18   1  남  rev  42  NaN  62.075     1 -0.274381
# 2925  강상주  제주  서귀포시  국회의원  18   2  남  con  53  NaN  62.075     0 -0.430158
# 2926  오영삼  제주  서귀포시  국회의원  18   3  남  con  45  NaN  62.075     0 -3.211616
# 2927  현애자  제주  서귀포시  국회의원  18   3  여  rev  45  NaN  62.075     0 -2.045857
# 2928  신명수  제주  서귀포시  국회의원  18   3  남  rem  49  NaN  62.075     0 -4.336344
#
#        학교   과목  경력_지역       인지도  지역구분
# 0     고려대    법      1  0.606031     3
# 1     고려대    법      0  0.349409     3
# 2     서울대  NaN      0  0.002581     3
# 3     NaN  NaN      0  0.000226     3
# 4     NaN  NaN      0  0.011147     3
# ...   ...  ...    ...       ...   ...
# 2924  NaN  NaN      0  0.870481     2
# 2925  NaN   경영      1  0.002289     2
# 2926  NaN  NaN      1  0.022829     2
# 2927  NaN  NaN      0  0.001494     2
# 2928  NaN  NaN      1  0.102906     2
#
# [2929 rows x 18 columns]
